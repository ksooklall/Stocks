# %% [markdown]
# # Crypto Analysis

# %%
from keras.layers.core import Dense, Activation, Dropout
from keras.layers.recurrent import LSTM
from keras.layers import Bidirectional
from keras.models import Sequential

from sklearn.metrics import mean_squared_error

import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def preprocessing(X):
    pass

# %%
df = pd.read_csv('bitcoin-historical-data/coinbaseUSD_1-min_data_2014-12-01_to_2018-01-08.csv')
len(df)
# Out:
# 1574274

# %%
coincheck_df = pd.read_csv('bitcoin-historical-data/coincheckJPY_1-min_data_2014-10-31_to_2018-01-08.csv')
coincheck_df.head()
# Out:
#     Timestamp   Open   High    Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1414735920  36880  36880  36880  36880        0.0951           3507.288
# 1  1414735980  36880  36880  36880  36880        0.0951           3507.288
# 2  1414736040  36880  36880  36880  36880        0.0951           3507.288
# 3  1414736100  36880  36880  36880  36880        0.0951           3507.288
# 4  1414736160  36880  36880  36880  36880        0.0951           3507.288
#
#    Weighted_Price
# 0         36880.0
# 1         36880.0
# 2         36880.0
# 3         36880.0
# 4         36880.0

# %%
bitstamp_df = pd.read_csv('bitcoin-historical-data/bitstampUSD_1-min_data_2012-01-01_to_2018-01-08.csv')
bitstamp_df.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980  4.39  4.39  4.39   4.39      0.455581                2.0
# 2  1325318040  4.39  4.39  4.39   4.39      0.455581                2.0
# 3  1325318100  4.39  4.39  4.39   4.39      0.455581                2.0
# 4  1325318160  4.39  4.39  4.39   4.39      0.455581                2.0
#
#    Weighted_Price
# 0            4.39
# 1            4.39
# 2            4.39
# 3            4.39
# 4            4.39

# %%
bit_df = pd.read_csv('bitcoin-historical-data/bitcoin_dataset.csv')
bit_df.head()
# Out:
#                   Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2009-11-10 00:00:00               0.0           1339450.0             0.0
# 1  2009-11-11 00:00:00               0.0           1342900.0             0.0
# 2  2009-11-12 00:00:00               0.0           1346400.0             0.0
# 3  2009-11-13 00:00:00               0.0           1349900.0             0.0
# 4  2009-11-14 00:00:00               0.0           1354050.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000215
# 1               0.0              0.0            0.000323
# 2               0.0              0.0            0.000215
# 3               0.0              0.0            0.000242
# 4               0.0              0.0            0.000216
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                    0.0                           1.0
# ...

# %%
bit_df['btc_blocks_size'].plot()
